# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline 
import seaborn as sns

# %%
tips= sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x=tips['size'])

# %%
sns.boxplot(x=tips['total_bill'])

# %%
#plot for 2 variable
sns.boxplot(x='sex', y='total_bill', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='time')

# %%
#Order by calender 
sns.boxplot(x='day', y='total_bill', data=tips, hue='time', order=['Sat', 'Sun', 'Thur', 'Fri'])

# %%
sns.boxplot(x='sex', y='tip', data=tips, order=['Female','Male'])

# %%
#Now we are going to use iris dataset

# %%
iris= sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Now boxplot for iris data
sns.boxplot(data=iris, palette='coolwarm')

# %%
#Horizontal boxplot 
sns.boxplot(data=iris, palette='coolwarm', orient='horizontal')

# %%
#Vertical boxplot 
sns.boxplot(data=iris, orient='v')

# %%
sns.boxplot(x='day', y='total_bill', data=tips )
sns.swarmplot(x='day', y='total_bill', data=tips )

# %%
sns.boxplot(x='day', y='total_bill', data=tips )
sns.swarmplot(x='day', y='total_bill', data=tips, color='black' )

# %%
sns.boxplot(x='day', y='total_bill', data=tips )
sns.swarmplot(x='day', y='total_bill', data=tips, color='0.35' )
